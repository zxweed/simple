# %% [markdown]
# # RSI(14) пересек 30 вниз - лонг лимитка на лой этой свечки. выход 4-16 свечек.

# %%
from simple.binance import getHistMonth
from simple.plotly import chartFigure
from simple.pretty import pp, pmap
import pandas as pd
import numpy as np
from talib import RSI
from functools import partial
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
frame = '1h'
period = 14
threshold = 30
duration = 5
fee = 0.08
tickers = ['XLMUSDT', 'ETHUSDT', 'LTCUSDT', 'TRXUSDT', 'BNBUSDT', 'ADAUSDT',
           'BTCUSDT', 'ETCUSDT', 'XRPUSDT', 'XMRUSDT', 'ZECUSDT', 'EOSUSDT']

# %%
def getOHLC(ticker: str) -> pd.Series:
    X = getHistMonth('2021-01', '2021-12', ticker, frame, spot=True)[['Open', 'High', 'Low', 'Close', 'Volume']]
    X.columns = pd.MultiIndex.from_product([[ticker], X.columns])
    return X

# %%
F = pd.concat(pmap(getOHLC, tickers), axis=1)
F
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
#                      XLMUSDT                                         ETHUSDT  \
#                         Open     High      Low    Close      Volume     Open
# DT
# 2021-01-01 00:00:00  0.12759  0.12896  0.12644  0.12879   6066035.9   736.42
# 2021-01-01 01:00:00  0.12879  0.13490  0.12879  0.13304  29171421.7   734.08
# 2021-01-01 02:00:00  0.13307  0.13329  0.13130  0.13272  10449260.8   748.27
# 2021-01-01 03:00:00  0.13274  0.13287  0.13082  0.13084   7853074.8   744.06
# 2021-01-01 04:00:00  0.13084  0.13584  0.13060  0.13340  19065493.4   744.87
# ...                      ...      ...      ...      ...         ...      ...
# 2021-12-31 19:00:00  0.26630  0.26640  0.25950  0.26010   5368913.0  3704.43
# 2021-12-31 20:00:00  0.26010  0.26280  0.25880  0.25960   5861754.0  3626.21
# 2021-12-31 21:00:00  0.25970  0.26640  0.25970  0.26580   5107216.0  3645.04
# 2021-12-31 22:00:00  0.26580  0.26750  0.26550  0.26690   1999409.0  3688.12
# 2021-12-31 23:00:00  0.26690  0.26850  0.26630  0.26650   1461244.0  3681.80
#
#                                                              ... ZECUSDT  \
#                         High      Low    Close       Volume  ...    Open
# DT                                                           ...
# 2021-01-01 00:00:00   739.00   729.33   734.07  27932.69884  ...   63.96
# 2021-01-01 01:00:00   749.00   733.37   748.28  52336.18779  ...   64.66
# 2021-01-01 02:00:00   749.00   742.27   744.06  33019.50100  ...   65.60
# 2021-01-01 03:00:00   747.23   743.10   744.82  17604.80859  ...   65.73
# 2021-01-01 04:00:00   747.09   739.30   742.29  18794.15424  ...   65.36
# ...                      ...      ...      ...          ...  ...     ...
# 2021-12-31 19:00:00  3705.93  3623.00  3626.27  20055.40060  ...  148.40
# 2021-12-31 20:00:00  3663.87  3622.29  3645.04  12289.97000  ...  144.90
# 2021-12-31 21:00:00  3701.85  3633.84  3688.41  13070.92930  ...  143.40
# 2021-12-31 22:00:00  3712.50  3673.55  3681.80   8131.40900  ...  145.60
# 2021-12-31 23:00:00  3697.90  3672.22  3676.23   6004.29100  ...  145.50
#
#                                                          EOSUSDT          \
#                        High     Low   Close       Volume    Open    High
# DT
# 2021-01-01 00:00:00   65.03   63.16   64.61   8351.08720  2.5906  2.6091
# 2021-01-01 01:00:00   65.73   64.58   65.60  13493.23174  2.6032  2.6350
# 2021-01-01 02:00:00   65.76   64.66   65.67   5936.09824  2.6329  2.6363
# 2021-01-01 03:00:00   66.40   65.35   65.36   9168.32065  2.6310  2.6493
# 2021-01-01 04:00:00   65.98   65.24   65.31   3602.43710  2.6353  2.6693
# ...                     ...     ...     ...          ...     ...     ...
# 2021-12-31 19:00:00  148.50  144.70  144.90  20496.64800  3.0480  3.0480
# 2021-12-31 20:00:00  146.50  143.30  143.40   8963.07100  2.9800  3.0100
# 2021-12-31 21:00:00  145.80  143.20  145.60   5103.24300  2.9820  3.0310
# 2021-12-31 22:00:00  146.70  145.30  145.50   5898.36600  3.0270  3.0480
# 2021-12-31 23:00:00  147.40  145.50  146.50   4156.64300  3.0350  3.0520
#
#
#                         Low   Close      Volume
# DT
# 2021-01-01 00:00:00  2.5670  2.6025   446540.68
# 2021-01-01 01:00:00  2.6014  2.6319   546405.18
# 2021-01-01 02:00:00  2.6116  2.6310   380641.80
# 2021-01-01 03:00:00  2.6292  2.6353   415831.43
# 2021-01-01 04:00:00  2.6294  2.6386   599350.29
# ...                     ...     ...         ...
# 2021-12-31 19:00:00  2.9760  2.9820  1148957.20
# 2021-12-31 20:00:00  2.9760  2.9820   483572.00
# 2021-12-31 21:00:00  2.9820  3.0260   520850.00
# 2021-12-31 22:00:00  3.0230  3.0350   315295.20
# 2021-12-31 23:00:00  3.0300  3.0340   191234.80
#
# [8747 rows x 60 columns]

# %%
def bt(ticker, period, threshold):
    C = F[ticker].copy()
    C['RSI'] = RSI(C.Close, period)

    def enterLong(row, threshold):
        return 1 if row[0] > threshold and row[1] < threshold else 0

    C['Target'] = C.RSI.rolling(window=2).apply(partial(enterLong, threshold=threshold)).shift()
    C['PrevLow'] = C.Low.shift()

    Pos = np.zeros(len(C))
    for index, row in enumerate(C.itertuples(index=False)):
        if row.Target > 0 and row.Low < row.PrevLow:
            Pos[index:index+duration] = 1

    C['Pos'] = Pos
    C['DPos'] = C.Pos.diff()
    C['Money'] = (-C.DPos * C.Low).cumsum()
    C['Fee'] = (C.DPos * C.Open * fee / 100).abs().cumsum()
    C['Balance'] = C.Money + C.Pos * C.Open
    return C

def getProfit(ticker, period, threshold):
    X = bt(ticker, period, threshold).Balance / F[ticker].Open[0] * 100
    X.name = ticker
    return X

# %%
P = pd.concat(pmap(partial(getProfit, period=period, threshold=threshold), tickers), axis=1)
P['Mean'] = P.mean(axis=1)
P
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
#                         XLMUSDT     ETHUSDT     LTCUSDT     TRXUSDT  \
# DT
# 2021-01-01 00:00:00         NaN         NaN         NaN         NaN
# 2021-01-01 01:00:00    0.000000    0.000000    0.000000    0.000000
# 2021-01-01 02:00:00    0.000000    0.000000    0.000000    0.000000
# 2021-01-01 03:00:00    0.000000    0.000000    0.000000    0.000000
# 2021-01-01 04:00:00    0.000000    0.000000    0.000000    0.000000
# ...                         ...         ...         ...         ...
# 2021-12-31 19:00:00  155.999686  422.269900  194.598293  202.465446
# 2021-12-31 20:00:00  157.018575  422.802205  194.598293  203.025775
# 2021-12-31 21:00:00  156.705071  425.359170  194.598293  203.063130
# 2021-12-31 22:00:00  161.486010  431.209093  194.598293  207.695181
# 2021-12-31 23:00:00  162.348146  430.350887  194.598293  207.471050
#
#                        BNBUSDT      ADAUSDT     BTCUSDT      ETCUSDT  \
# DT
# 2021-01-01 00:00:00        NaN          NaN         NaN          NaN
# 2021-01-01 01:00:00    0.00000     0.000000    0.000000     0.000000
# 2021-01-01 02:00:00    0.00000     0.000000    0.000000     0.000000
# 2021-01-01 03:00:00    0.00000     0.000000    0.000000     0.000000
# 2021-01-01 04:00:00    0.00000     0.000000    0.000000     0.000000
# ...                        ...          ...         ...          ...
# 2021-12-31 19:00:00  901.07469  1457.008933  135.489736  1776.730416
# 2021-12-31 20:00:00  901.07469  1457.008933  135.663573  1778.321196
# 2021-12-31 21:00:00  901.07469  1457.008933  136.211153  1778.497950
# 2021-12-31 22:00:00  901.07469  1457.008933  137.757329  1788.396140
# 2021-12-31 23:00:00  901.07469  1457.008933  137.653987  1788.749646
#
#                         XRPUSDT    XMRUSDT     ZECUSDT     EOSUSDT        Mean
# DT
# 2021-01-01 00:00:00         NaN        NaN         NaN         NaN         NaN
# 2021-01-01 01:00:00    0.000000   0.000000    0.000000    0.000000    0.000000
# 2021-01-01 02:00:00    0.000000   0.000000    0.000000    0.000000    0.000000
# 2021-01-01 03:00:00    0.000000   0.000000    0.000000    0.000000    0.000000
# 2021-01-01 04:00:00    0.000000   0.000000    0.000000    0.000000    0.000000
# ...                         ...        ...         ...         ...         ...
# 2021-12-31 19:00:00  855.555049  58.130602  237.585991  245.167143  553.506324
# 2021-12-31 20:00:00  856.010568  58.130602  240.087555  245.167143  554.075759
# 2021-12-31 21:00:00  860.520202  58.130602  237.742339  245.167143  554.506556
# 2021-12-31 22:00:00  867.261878  58.130602  241.181989  245.167143  557.580607
# 2021-12-31 23:00:00  865.758666  58.130602  241.025641  245.167143  557.444807
#
# [8747 rows x 13 columns]

# %%
D = {col: P[col] for col in P.columns}
D['Mean'] = dict(y=P.Mean, color='black', width=6)

chartFigure(**D)
# Out:
# FigureWidgetResampler({
#     'data': [{'name': '<b style="color:sandybrown">[R]</b> XLMUSDT <i style="color:#fc…

# %%
# detailed chart
C = bt('ETHUSDT', period=period, threshold=threshold)
C
# Out:
#                         Open     High      Low    Close       Volume  \
# DT
# 2021-01-01 00:00:00   736.42   739.00   729.33   734.07  27932.69884
# 2021-01-01 01:00:00   734.08   749.00   733.37   748.28  52336.18779
# 2021-01-01 02:00:00   748.27   749.00   742.27   744.06  33019.50100
# 2021-01-01 03:00:00   744.06   747.23   743.10   744.82  17604.80859
# 2021-01-01 04:00:00   744.87   747.09   739.30   742.29  18794.15424
# ...                      ...      ...      ...      ...          ...
# 2021-12-31 19:00:00  3704.43  3705.93  3623.00  3626.27  20055.40060
# 2021-12-31 20:00:00  3626.21  3663.87  3622.29  3645.04  12289.97000
# 2021-12-31 21:00:00  3645.04  3701.85  3633.84  3688.41  13070.92930
# 2021-12-31 22:00:00  3688.12  3712.50  3673.55  3681.80   8131.40900
# 2021-12-31 23:00:00  3681.80  3697.90  3672.22  3676.23   6004.29100
#
#                            RSI  Target  PrevLow  Pos  DPos    Money  \
# DT
# 2021-01-01 00:00:00        NaN     NaN      NaN  0.0   NaN      NaN
# 2021-01-01 01:00:00        NaN     NaN   729.33  0.0   0.0     0.00
# 2021-01-01 02:00:00        NaN     NaN   733.37  0.0   0.0     0.00
# 2021-01-01 03:00:00        NaN     NaN   742.27  0.0   0.0     0.00
# 2021-01-01 04:00:00        NaN     NaN   743.10  0.0   0.0     0.00
# ...                        ...     ...      ...  ...   ...      ...
# 2021-12-31 19:00:00  29.592179     0.0  3695.16  0.0   0.0  3109.68
# 2021-12-31 20:00:00  34.021059     1.0  3623.00  1.0   1.0  -512.61
# 2021-12-31 21:00:00  42.950686     0.0  3622.29  1.0   0.0  -512.61
# 2021-12-31 22:00:00  42.017317     0.0  3633.84  1.0   0.0  -512.61
# 2021-12-31 23:00:00  41.204733     0.0  3673.55  1.0   0.0  -512.61
#
#                             Fee  Balance
# DT
# 2021-01-01 00:00:00         NaN      NaN
# 2021-01-01 01:00:00    0.000000     0.00
# 2021-01-01 02:00:00    0.000000     0.00
# 2021-01-01 03:00:00    0.000000     0.00
# 2021-01-01 04:00:00    0.000000     0.00
# ...                         ...      ...
# 2021-12-31 19:00:00  300.671688  3109.68
# 2021-12-31 20:00:00  303.572656  3113.60
# 2021-12-31 21:00:00  303.572656  3132.43
# 2021-12-31 22:00:00  303.572656  3175.51
# 2021-12-31 23:00:00  303.572656  3169.19
#
# [8747 rows x 13 columns]

# %%
Buy = C[C.DPos > 0]
Sell = C[C.DPos < 0]

# %%
fig = go.FigureWidget(make_subplots(rows=3, cols=1, shared_xaxes=True, vertical_spacing=0,
                                    row_heights=[0.7, 0.15, 0.15], specs=[[{"secondary_y": True}], [{}], [{}]]))

fig.update_layout(autosize=True, height=800, template='plotly_white',
                  legend=dict(x=0.1, y=1.01, orientation="h"),
                  margin=dict(l=45, r=5, b=10, t=10, pad=3),
                  xaxis_rangeslider_visible=False,
                  yaxis2_showgrid=False)

fig.add_candlestick(x=C.index, open=C.Open, high=C.High, low=C.Low, close=C.Close, name='OHLC', opacity=0.5)
fig.add_scattergl(name='Buy', mode='markers', x=Buy.index, y=Buy.PrevLow, marker=dict(symbol='triangle-up', color='green', size=10)) 
fig.add_scattergl(name='Sell', mode='markers', x=Sell.index, y=Sell.Open, marker=dict(symbol='triangle-down', color='red', size=10))

fig.add_trace(go.Scattergl(x=C.index, y=C.Balance, name='Balance', line_color='blue', connectgaps=True, line_shape='hv'), secondary_y=True)
fig.add_trace(go.Scattergl(x=C.index, y=C.Fee, name='Fee', line_color='red', connectgaps=True), secondary_y=True)

fig.add_scattergl(name='RSI', x=C.index, y=C.RSI, row=2, col=1)
fig.add_bar(name='Long', x=C.index, y=C.Pos, marker_color='green', row=3, col=1, opacity=0.5)
fig.add_scattergl(x=C.index, y=C.Target/2, name='Target', row=3, col=1, line_color='green', connectgaps=True)

fig.update_xaxes(spikemode='across+marker', spikedash='dot', spikethickness=1, spikesnap='cursor')
fig.update_traces(xaxis='x1')
fig.update_xaxes(showgrid=True, title='Time', visible=True, showticklabels=True)

fig
# Out:
# FigureWidget({
#     'data': [{'close': array([ 734.07,  748.28,  744.06, ..., 3688.41, 3681.8 , 3676.23]),
#     …
